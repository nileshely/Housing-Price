# %% [markdown]
# # Report: Real Estate Prices

# %% [markdown]
# # Introduction:
#
# The housing price dataset presented here encapsulates a rich repository of property listings, comprising diverse attributes ranging from the number of bedrooms and bathrooms to living area size, lot size, and location details. With over 21 columns and 21,613 records, this dataset offers a comprehensive insight into the dynamics of the real estate market. Its utility spans across a spectrum of data analysis and machine learning applications, making it invaluable for stakeholders such as investors, real estate agents, policymakers, and data scientists.
#
# Understanding the intricacies of the housing market is paramount for making informed decisions, whether it be for investment purposes, property valuation, or policy formulation. The dataset serves as a cornerstone for predictive modeling, enabling forecasts of property prices based on a multitude of features including location, amenities, and structural attributes. Moreover, it facilitates the identification of trends and patterns within the real estate landscape, thereby empowering stakeholders with actionable insights to navigate the market effectively.
#
# In this analysis, we delve into the dataset, leveraging data visualization techniques to unearth key insights and trends. Through a series of visualizations, we explore the distribution of prices, the relationship between various attributes and property prices, as well as other pertinent factors such as property condition, location, and neighborhood characteristics. By elucidating these insights, our aim is to provide stakeholders with a deeper understanding of the housing market dynamics and equip them with the knowledge necessary to make informed decisions.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
housing_data = pd.read_csv("/kaggle/input/housing-price-dataset/Housing.csv")

# %%
housing_data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7229300521  20141013T000000  231300.0         2       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
housing_data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580306e+09  5.400886e+05      3.370795      2.114757   2079.899736
# std    2.876570e+09  3.671268e+05      0.930105      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
sns.set_style("whitegrid")

# %%
# Visualization 1: Distribution of Prices
plt.figure(figsize=(10, 6))
sns.histplot(housing_data['price'], bins=30, color='blue', kde=True)
plt.xlabel('Price ($)')
plt.ylabel('Frequency')
plt.title('Distribution of Prices')
plt.show()

# %%
# Visualization 2: Number of Bedrooms
plt.figure(figsize=(10, 6))
sns.countplot(x='bedrooms', data=housing_data, palette='Blues_d')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Count')
plt.title('Number of Bedrooms')
plt.show()

# %%
# Visualization 3: Number of Bathrooms
plt.figure(figsize=(10, 6))
sns.countplot(x='bathrooms', data=housing_data, palette='Blues_d')
plt.xlabel('Number of Bathrooms')
plt.ylabel('Count')
plt.title('Number of Bathrooms')
plt.xticks(rotation=90)
plt.show()

# %%
# Visualization 4: Scatter plot of Living Area vs Price
plt.figure(figsize=(10, 6))
sns.scatterplot(x='sqft_living', y='price', data=housing_data, color='blue')
plt.xlabel('Living Area (sqft)')
plt.ylabel('Price ($)')
plt.title('Living Area vs Price')
plt.show()

# %%
# Visualization 5: Scatter plot of Lot Size vs Price
plt.figure(figsize=(10, 6))
sns.scatterplot(x='sqft_lot', y='price', data=housing_data, color='blue')
plt.xlabel('Lot Size (sqft)')
plt.ylabel('Price ($)')
plt.title('Lot Size vs Price')
plt.show()

# %%
# Visualization 6: Boxplot of Price by Grade
plt.figure(figsize=(10, 6))
sns.boxplot(x='grade', y='price', data=housing_data, palette='Blues_d')
plt.xlabel('Grade')
plt.ylabel('Price ($)')
plt.title('Price by Grade')
plt.show()

# %%
# Visualization 7: Boxplot of Price by Waterfront
plt.figure(figsize=(10, 6))
sns.boxplot(x='waterfront', y='price', data=housing_data, palette='Blues_d')
plt.xlabel('Waterfront (0: No, 1: Yes)')
plt.ylabel('Price ($)')
plt.title('Price by Waterfront')
plt.show()

# %%
# Visualization 8: Distribution of Year Built
plt.figure(figsize=(10, 6))
sns.histplot(housing_data['yr_built'], bins=30, color='blue', kde=True)
plt.xlabel('Year Built')
plt.ylabel('Frequency')
plt.title('Distribution of Year Built')
plt.show()

# %%
# Visualization 9: Distribution of Renovation Year
plt.figure(figsize=(10, 6))
sns.histplot(housing_data['yr_renovated'], bins=30, color='blue', kde=True)
plt.xlabel('Year Renovated')
plt.ylabel('Frequency')
plt.title('Distribution of Renovation Year')
plt.show()

# %%
# Visualization 10: Count of Properties by Condition
plt.figure(figsize=(10, 6))
sns.countplot(x='condition', data=housing_data, palette='Blues_d')
plt.xlabel('Condition')
plt.ylabel('Count')
plt.title('Count of Properties by Condition')
plt.show()

# %%
# Visualization 11: Scatter plot of Latitude vs Longitude
plt.figure(figsize=(10, 6))
sns.scatterplot(x='long', y='lat', data=housing_data, color='blue')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Latitude vs Longitude')
plt.show()

# %%
# Visualization 12: Distribution of Living Area (15 nearest neighbors)
plt.figure(figsize=(10, 6))
sns.histplot(housing_data['sqft_living15'], bins=30, color='blue', kde=True)
plt.xlabel('Living Area of 15 Nearest Neighbors (sqft)')
plt.ylabel('Frequency')
plt.title('Distribution of Living Area (15 nearest neighbors)')
plt.show()

# %%
# Visualization 13: Distribution of Lot Size (15 nearest neighbors)
plt.figure(figsize=(10, 6))
sns.histplot(housing_data['sqft_lot15'], bins=30, color='blue', kde=True)
plt.xlabel('Lot Size of 15 Nearest Neighbors (sqft)')
plt.ylabel('Frequency')
plt.title('Distribution of Lot Size (15 nearest neighbors)')
plt.show()

# %%
# Visualization 14: Count of Properties by Zipcode
plt.figure(figsize=(14, 6))
sns.countplot(x='zipcode', data=housing_data, palette='Blues_d')
plt.xlabel('Zipcode')
plt.ylabel('Count')
plt.title('Count of Properties by Zipcode')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Conclusion:
#
# In conclusion, the housing price dataset and the accompanying data visualizations offer a multifaceted perspective on the real estate market. Through exploratory analysis and visualization, we have uncovered several key insights that shed light on the factors influencing property prices and market dynamics.
#
# The distribution of prices revealed varied trends, with certain price ranges being more prevalent than others, indicative of market segmentation. Additionally, the scatter plots elucidated the relationship between price and attributes such as living area, lot size, and grade, highlighting their significance in determining property values. Furthermore, the distribution of features such as bedrooms, bathrooms, and condition provided insights into the composition and quality of properties within the dataset.
#
# Moreover, the spatial analysis of location attributes, including latitude, longitude, and zipcode, offered insights into geographical patterns and localized variations in property prices. These insights are invaluable for stakeholders seeking to identify lucrative investment opportunities, target specific market segments, or optimize their real estate strategies.
#
# Overall, the housing price dataset, coupled with data visualization techniques, serves as a powerful tool for understanding and navigating the complexities of the housing market. By harnessing the insights gleaned from this analysis, stakeholders can make data-driven decisions that are grounded in empirical evidence, ultimately enhancing their ability to thrive in the dynamic realm of real estate.
